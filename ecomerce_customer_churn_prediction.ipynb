# %% [markdown]
# # E-Commerce Customer Churn

# %% [markdown]
# ## Latar belakang dan Permasalahan

# %% [markdown]
# **Latar Belakang :**
#
# analisis data yang efisien dapat mengambil keputusan yang cepat dan tepat. Untuk itu, dibutuhkan beberapa metode analisis yang sesuai dengan data, dan Machine Learning bisa menjadi solusi karena mampu menganalisis data besar dalam waktu singkat.
#
#
#
# **Permasalahan :**
#
# Analisis data dalam jumlah besar membutuhkan waktu beberapa jam - beberapa hari (3-7 hari) jika dilakukan secara manual. Diperlukan penerapan Machine Learning yang membutuhkan waktu beberapa detik hingga puluhan menit tergantung jumlah datanya.

# %% [markdown]
# ** Tujuan Evaluasi :**
# Tujuan evaluasi model adalah untuk mengoptimalkan F1 Score. F1 Score dipilih karena perusahaan masih baru dalam menggunakan machine learning, sehingga membutuhkan metrik yang menyeimbangkan antara Precision dan Recall

# %% [markdown]
# # DATA UNDERSTANDING

# %% [markdown]
# ## Load data

# %%
import pandas as pd

data = pd.read_csv('data_ecommerce_customer_churn.csv')
data
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0       15.0             29.0                         4  Laptop & Accessory
# 1        7.0             25.0                         4              Mobile
# 2       27.0             13.0                         3  Laptop & Accessory
# 3       20.0             25.0                         4             Fashion
# 4       30.0             15.0                         4              Others
# ...      ...              ...                       ...                 ...
# 3936    28.0              9.0                         5             Fashion
# 3937     8.0              7.0                         2        Mobile Phone
# 3938    30.0              6.0                         5  Laptop & Accessory
# 3939     6.0              NaN                         4              Mobile
# 3940     2.0              7.0                         3  Laptop & Accessory
#
#       SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                     3        Single                2         0
# 1                     1       Married                2         0
# 2                     1       Married                5         0
# 3                     3      Divorced                7         0
# 4                     4        Single                8         0
# ...                 ...           ...              ...       ...
# 3936                  3       Married                8         0
# 3937                  2        Single                4         0
# 3938                  3       Married                3         1
# 3939                  3       Married               10         1
# 3940                  5       Married                1         0
#
#       DaySinceLastOrder  CashbackAmount  Churn
# 0                   7.0          143.32      0
# 1                   7.0          129.29      0
# 2                   7.0          168.54      0
# 3                   NaN          230.27      0
# 4                   8.0          322.17      0
# ...                 ...             ...    ...
# 3936                1.0          231.86      0
# 3937                4.0          157.80      0
# 3938                2.0          156.60      0
# 3939                0.0          124.37      1
# 3940                2.0          153.73      0
#
# [3941 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3941 entries, 0 to 3940
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tenure                    3747 non-null   float64
#  1   WarehouseToHome           3772 non-null   float64
#  2   NumberOfDeviceRegistered  3941 non-null   int64
#  3   PreferedOrderCat          3941 non-null   object
#  4   SatisfactionScore         3941 non-null   int64
#  5   MaritalStatus             3941 non-null   object
#  6   NumberOfAddress           3941 non-null   int64
#  7   Complain                  3941 non-null   int64
#  8   DaySinceLastOrder         3728 non-null   float64
#  9   CashbackAmount            3941 non-null   float64
#  10  Churn                     3941 non-null   int64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 338.8+ KB

# %% [markdown]
# ## Type data

# %%
data_kategorik = data.select_dtypes(include='object').columns
data_kategorik
# Out:
# Index(['PreferedOrderCat', 'MaritalStatus'], dtype='object')

# %%
data_numerik = data.select_dtypes(include='number').columns
data_numerik
# Out:
# Index(['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
#        'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
#        'CashbackAmount', 'Churn'],
#       dtype='object')

# %%
len(data_kategorik)
# Out:
# 2

# %%
len(data_numerik)
# Out:
# 9

# %% [markdown]
# ## deskripsi fitur dan label

# %% [markdown]
# | **Fitur**                    | **Deskripsi**                                                                                                             |
# | ---------------------------- | ------------------------------------------------------------------------------------------------------------------------- |
# | **Tenure**                   | Lama waktu pelanggan bergabung dengan perusahaan. Biasanya dalam bulan atau tahun.                                        |
# | **WarehouseToHome**          | Jarak antara gudang ke rumah pelanggan (kemungkinan dalam km atau mil).                                                   |
# | **NumberOfDeviceRegistered** | Jumlah perangkat yang terdaftar oleh pelanggan. Semakin banyak perangkat, bisa jadi menunjukkan keterlibatan yang tinggi. |
# | **PreferedOrderCat**         | Kategori produk yang paling sering dipesan dalam bulan terakhir. Ini biasanya data kategorikal.                           |
# | **SatisfactionScore**        | Skor kepuasan pelanggan (mungkin dari 1–5 atau 1–10).                                                                     |
# | **MaritalStatus**            | Status pernikahan pelanggan (kategorikal, misal: "Married", "Single", dll).                                               |
# | **NumberOfAddress**          | Jumlah alamat yang ditambahkan oleh pelanggan. Bisa jadi indikator mobilitas atau keaktifan.                              |
# | **Complaint**                | Apakah pelanggan mengajukan komplain bulan lalu (Boolean: Ya/Tidak atau 1/0).                                             |
# | **DaySinceLastOrder**        | Jumlah hari sejak terakhir kali pelanggan memesan.                                                                        |
# | **CashbackAmount**           | Rata-rata cashback yang diterima pelanggan dalam bulan lalu.                                                              |
# | **Churn**                    | Label target. Menunjukkan apakah pelanggan churn atau tidak (biasanya 0 = tidak churn, 1 = churn).                        |

# %% [markdown]
# ## Data Agg

# %%
data.select_dtypes(include='number').describe()
# Out:
#             Tenure  WarehouseToHome  NumberOfDeviceRegistered  \
# count  3747.000000      3772.000000               3941.000000
# mean     10.081398        15.650583                  3.679269
# std       8.498864         8.452301                  1.013938
# min       0.000000         5.000000                  1.000000
# 25%       2.000000         9.000000                  3.000000
# 50%       9.000000        14.000000                  4.000000
# 75%      16.000000        21.000000                  4.000000
# max      61.000000       127.000000                  6.000000
#
#        SatisfactionScore  NumberOfAddress     Complain  DaySinceLastOrder  \
# count        3941.000000      3941.000000  3941.000000        3728.000000
# mean            3.088302         4.237757     0.282416           4.531652
# std             1.381832         2.626699     0.450232           3.667648
# min             1.000000         1.000000     0.000000           0.000000
# 25%             2.000000         2.000000     0.000000           2.000000
# 50%             3.000000         3.000000     0.000000           3.000000
# 75%             4.000000         6.000000     1.000000           7.000000
# max             5.000000        22.000000     1.000000          46.000000
#
#        CashbackAmount        Churn
# count     3941.000000  3941.000000
# mean       176.707419     0.171023
# std         48.791784     0.376576
# min          0.000000     0.000000
# 25%        145.700000     0.000000
# 50%        163.340000     0.000000
# 75%        195.250000     0.000000
# max        324.990000     1.000000

# %% [markdown]
# ## Missing value dan Value 0

# %% [markdown]
# ### Missing value

# %%
missing_value = data.isna().sum().reset_index(name='Jumlah Missing Value')
missing_value['persentase'] = round(missing_value['Jumlah Missing Value'] / len(data) * 100, 2)
missing_value.sort_values(by='persentase', ascending=False).head(5)
# Out:
#                       index  Jumlah Missing Value  persentase
# 8         DaySinceLastOrder                   213        5.40
# 0                    Tenure                   194        4.92
# 1           WarehouseToHome                   169        4.29
# 2  NumberOfDeviceRegistered                     0        0.00
# 3          PreferedOrderCat                     0        0.00

# %% [markdown]
# ### Value 0

# %%
value_0 = data.isin([0]).sum().reset_index(name='Jumlah Value 0')
value_0['persentase'] = round(value_0['Jumlah Value 0'] / len(data) * 100, 2)
value_0.sort_values(by='persentase', ascending=False).head(5)
# Out:
#                 index  Jumlah Value 0  persentase
# 10              Churn            3267       82.90
# 7            Complain            2828       71.76
# 0              Tenure             347        8.80
# 8   DaySinceLastOrder             345        8.75
# 9      CashbackAmount               3        0.08

# %% [markdown]
# karena churn dan complain itu menjukan langganan/tidak dan iya/tidak
#
# tenure 0 itu adalah pelanggan yang baru bergabung
#
# DaySinceLastOrder 0 adalah pelanggan yang baru melakukan order hari ini
#
# CashbackAmount 0 adalah pelanggan tidak menerima cashback dalam periode tertentu

# %% [markdown]
# jadi kesimpulannya ini tidak perlu di imputasi kemungkinan data ini valid dikarenakan dalam transaksi di ecomerce emmungkin pelanggan baru bergabung bisa memesan banyak product dan saat pesanan nya tiba bisa juga komplain dan langsung memutus berlanggan atau tidak dan ini sangat wajar ditengah persaingan ecomerce

# %% [markdown]
# ## Duplikat

# %%
data.duplicated().sum()
# Out:
# np.int64(671)

# %%
data_d = data[data.duplicated(keep=False)]
data_d.sort_values(by=list(data.columns)).head(10)
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 2974     0.0              6.0                         3  Laptop & Accessory
# 3576     0.0              6.0                         3  Laptop & Accessory
# 300      0.0              6.0                         3              Mobile
# 575      0.0              6.0                         3              Mobile
# 1364     0.0              6.0                         4              Mobile
# 2821     0.0              6.0                         4              Mobile
# 640      0.0              6.0                         4        Mobile Phone
# 3333     0.0              6.0                         4        Mobile Phone
# 767      0.0              8.0                         1  Laptop & Accessory
# 1696     0.0              8.0                         1  Laptop & Accessory
#
#       SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 2974                  4       Married                2         0
# 3576                  4       Married                2         0
# 300                   4        Single                2         1
# 575                   4        Single                2         1
# 1364                  4        Single                2         0
# 2821                  4        Single                2         0
# 640                   3        Single                1         1
# 3333                  3        Single                1         1
# 767                   3       Married                2         0
# 1696                  3       Married                2         0
#
#       DaySinceLastOrder  CashbackAmount  Churn
# 2974                4.0          163.97      0
# 3576                4.0          163.97      0
# 300                 4.0          132.02      1
# 575                 4.0          132.02      1
# 1364                0.0          128.36      0
# 2821                0.0          128.36      0
# 640                 2.0          137.30      1
# 3333                2.0          137.30      1
# 767                 7.0          152.06      0
# 1696                7.0          152.06      0

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.reset_index(drop=True, inplace=True)
data
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0       15.0             29.0                         4  Laptop & Accessory
# 1        7.0             25.0                         4              Mobile
# 2       27.0             13.0                         3  Laptop & Accessory
# 3       20.0             25.0                         4             Fashion
# 4       30.0             15.0                         4              Others
# ...      ...              ...                       ...                 ...
# 3265    25.0             15.0                         5             Fashion
# 3266    26.0              7.0                         4             Grocery
# 3267    28.0              9.0                         5             Fashion
# 3268     8.0              7.0                         2        Mobile Phone
# 3269     2.0              7.0                         3  Laptop & Accessory
#
#       SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                     3        Single                2         0
# 1                     1       Married                2         0
# 2                     1       Married                5         0
# 3                     3      Divorced                7         0
# 4                     4        Single                8         0
# ...                 ...           ...              ...       ...
# 3265                  4       Married                7         0
# 3266                  1       Married                4         0
# 3267                  3       Married                8         0
# 3268                  2        Single                4         0
# 3269                  5       Married                1         0
#
#       DaySinceLastOrder  CashbackAmount  Churn
# 0                   7.0          143.32      0
# 1                   7.0          129.29      0
# 2                   7.0          168.54      0
# 3                   NaN          230.27      0
# 4                   8.0          322.17      0
# ...                 ...             ...    ...
# 3265                8.0          249.90      0
# 3266                9.0          295.99      0
# 3267                1.0          231.86      0
# 3268                4.0          157.80      0
# 3269                2.0          153.73      0
#
# [3270 rows x 11 columns]

# %% [markdown]
# ## save data ( digunakan untuk machine learning, tidak ada duplikat)

# %%
data.to_csv('data_ml.csv', index=False)

# %% [markdown]
# ## kesimpulan

# %% [markdown]
# - data memiliki 3941 rows dan 11 columns
# - type data 2 column kategorik dan 9 column numerik
# - data describenya tidak ada value yang mines
#
# - ada beberapa column yang memiliki missing value yaitu :
# 1. DaySinceLastOrder :	213
# 2. Tenure	: 194
# 3. WarehouseToHome	: 169
#
# - dan ada yang memiliki value 0 tapi disini value 0 itu valid dikarenakan :
# 1. churn dan complain itu menjukan langganan/tidak dan iya/tidak
# 2. tenure 0 itu adalah pelanggan yang baru bergabung
# 3. DaySinceLastOrder 0 adalah pelanggan yang baru melakukan order hari ini
# 4. ashbackAmount 0 adalah pelanggan tidak menerima cashback dalam periode tertentu
#
# - data memiliki duplikat sebanyak 671
# - save data yang tidak mengandung duplikat untuk digunakan saat di machine learning

# %% [markdown]
# # CLEANING DENGAN KNN IMPUTER ( HANYA UNTUK EDA, BUKAN UNTUK SEBELUM SPLITING )

# %% [markdown]
# ### Catatan Rekomendasi n_neighbors
#
# | Ukuran Data   | Rekomendasi `n_neighbors` |
# | ------------- | ------------------------- |
# | Kecil (<1000) | 3–5                       |
# | Sedang        | 5–10                      |
# | Besar         | 10+                       |

# %% [markdown]
# ### preparation

# %%
import pandas as pd

data_knn = pd.read_csv('data_ecommerce_customer_churn.csv')
data_knn.drop_duplicates(inplace=True)
data_knn.reset_index(drop=True, inplace=True)
data_knn
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0       15.0             29.0                         4  Laptop & Accessory
# 1        7.0             25.0                         4              Mobile
# 2       27.0             13.0                         3  Laptop & Accessory
# 3       20.0             25.0                         4             Fashion
# 4       30.0             15.0                         4              Others
# ...      ...              ...                       ...                 ...
# 3265    25.0             15.0                         5             Fashion
# 3266    26.0              7.0                         4             Grocery
# 3267    28.0              9.0                         5             Fashion
# 3268     8.0              7.0                         2        Mobile Phone
# 3269     2.0              7.0                         3  Laptop & Accessory
#
#       SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                     3        Single                2         0
# 1                     1       Married                2         0
# 2                     1       Married                5         0
# 3                     3      Divorced                7         0
# 4                     4        Single                8         0
# ...                 ...           ...              ...       ...
# 3265                  4       Married                7         0
# 3266                  1       Married                4         0
# 3267                  3       Married                8         0
# 3268                  2        Single                4         0
# 3269                  5       Married                1         0
#
#       DaySinceLastOrder  CashbackAmount  Churn
# 0                   7.0          143.32      0
# 1                   7.0          129.29      0
# 2                   7.0          168.54      0
# 3                   NaN          230.27      0
# 4                   8.0          322.17      0
# ...                 ...             ...    ...
# 3265                8.0          249.90      0
# 3266                9.0          295.99      0
# 3267                1.0          231.86      0
# 3268                4.0          157.80      0
# 3269                2.0          153.73      0
#
# [3270 rows x 11 columns]

# %%
data_knn.isna().sum().sort_values(ascending=False).head(5)
# Out:
# DaySinceLastOrder           181
# Tenure                      160
# WarehouseToHome             135
# NumberOfDeviceRegistered      0
# PreferedOrderCat              0
# dtype: int64

# %% [markdown]
# ### Imputasi

# %%
from sklearn.impute import KNNImputer

data_num = data_knn.select_dtypes(include='number')

# Buat salinan data
data_num_knn = data_num.copy()

# Inisialisasi dan fit-transform
knn_imputer = KNNImputer(n_neighbors=5)
data_imputed = knn_imputer.fit_transform(data_num_knn)

# Masukkan kembali hasilnya ke DataFrame
data_knn_imputed = pd.DataFrame(data_imputed, columns=data_num.columns)

data_knn_imputed.isna().sum().sort_values(ascending=False)
# Out:
# Tenure                      0
# WarehouseToHome             0
# NumberOfDeviceRegistered    0
# SatisfactionScore           0
# NumberOfAddress             0
# Complain                    0
# DaySinceLastOrder           0
# CashbackAmount              0
# Churn                       0
# dtype: int64

# %%
data_knn_imputed
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered  SatisfactionScore  \
# 0       15.0             29.0                       4.0                3.0
# 1        7.0             25.0                       4.0                1.0
# 2       27.0             13.0                       3.0                1.0
# 3       20.0             25.0                       4.0                3.0
# 4       30.0             15.0                       4.0                4.0
# ...      ...              ...                       ...                ...
# 3265    25.0             15.0                       5.0                4.0
# 3266    26.0              7.0                       4.0                1.0
# 3267    28.0              9.0                       5.0                3.0
# 3268     8.0              7.0                       2.0                2.0
# 3269     2.0              7.0                       3.0                5.0
#
#       NumberOfAddress  Complain  DaySinceLastOrder  CashbackAmount  Churn
# 0                 2.0       0.0                7.0          143.32    0.0
# 1                 2.0       0.0                7.0          129.29    0.0
# 2                 5.0       0.0                7.0          168.54    0.0
# 3                 7.0       0.0                6.0          230.27    0.0
# 4                 8.0       0.0                8.0          322.17    0.0
# ...               ...       ...                ...             ...    ...
# 3265              7.0       0.0                8.0          249.90    0.0
# 3266              4.0       0.0                9.0          295.99    0.0
# 3267              8.0       0.0                1.0          231.86    0.0
# 3268              4.0       0.0                4.0          157.80    0.0
# 3269              1.0       0.0                2.0          153.73    0.0
#
# [3270 rows x 9 columns]

# %% [markdown]
# ### Save data

# %%
import pandas as pd

data_knn_imputed.to_csv('data_clean_knn.csv', index=False)

# %% [markdown]
# saya menggunakan knn imputer hanya untuk digunakan explorasi data,bukan digunakan di modeling dikarenakan tidak boleh melakukan imputasi sebelum spilt data

# %% [markdown]
# dan menyimpan datanya untuk dipakai saat EDA

# %% [markdown]
# # EXPLORASI DATA

# %%
import pandas as pd

data_knn = pd.read_csv('data_clean_knn.csv')
data_knn.columns
# Out:
# Index(['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
#        'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
#        'CashbackAmount', 'Churn'],
#       dtype='object')

# %% [markdown]
# ### Distribusi

# %% [markdown]
# 1. grafik distribusi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cols = ['Churn','Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']

# Plot distribusi dan outlier
plt.figure(figsize=(20, 30))

for i, col in enumerate(cols):
    plt.subplot(10, 4, i+1)
    sns.histplot(data_knn[col], kde=True, color='skyblue')
    plt.title(f'Distribusi {col}')


plt.tight_layout()
plt.show()

# %% [markdown]
# 2. uji normalitas distribusi

# %%
import scipy.stats as stats
import numpy as np
import pandas as pd

cols = data_knn[cols]

# Uji Shapiro-Wilk
for col in cols.columns:
    stat, p = stats.shapiro(cols[col])
    print(f"Kolom: {col}")
    print(f"  Shapiro-Wilk Test Statistic: {stat}")
    print(f"  Shapiro-Wilk p-value: {p}")
    if p > 0.05:
        print(f"{col} memiliki distribusi normal.\n")
    else:
        print(f"{col} tidak memiliki distribusi normal.\n")
# Out:
# Kolom: Churn
#   Shapiro-Wilk Test Statistic: 0.4449344901605755
#   Shapiro-Wilk p-value: 2.457281091471925e-72
# Churn tidak memiliki distribusi normal.
#
# Kolom: Tenure
#   Shapiro-Wilk Test Statistic: 0.9123277814671713
#   Shapiro-Wilk p-value: 6.322300144474641e-40
# Tenure tidak memiliki distribusi normal.
#
# Kolom: WarehouseToHome
#   Shapiro-Wilk Test Statistic: 0.8657257264654443
#   Shapiro-Wilk p-value: 1.5512053720871941e-46
# WarehouseToHome tidak memiliki distribusi normal.
#
# Kolom: NumberOfDeviceRegistered
#   Shapiro-Wilk Test Statistic: 0.8953027055237042
#   Shapiro-Wilk p-value: 1.2966212251170327e-42
# NumberOfDeviceRegistered tidak memiliki distribusi normal.
#
# Kolom: SatisfactionScore
#   Shapiro-Wilk Test Statistic: 0.8864589908094078
#   Shapiro-Wilk p-value: 7.148555143335306e-44
# SatisfactionScore tidak memiliki distribusi normal.
#
# Kolom: NumberOfAddress
#   Shapiro-Wilk Test Statistic: 0.8743731532477483
#   Shapiro-Wilk p-value: 1.8095995576352524e-45
# NumberOfAddress tidak memiliki distribusi normal.
#
# Kolom: Complain
#   Shapiro-Wilk Test Statistic: 0.5632480056868956
#   Shapiro-Wilk p-value: 1.4394320317291071e-67
# Complain tidak memiliki distribusi normal.
#
# Kolom: DaySinceLastOrder
#   Shapiro-Wilk Test Statistic: 0.8992142297712207
#   Shapiro-Wilk p-value: 4.9798884412770584e-42
# DaySinceLastOrder tidak memiliki distribusi normal.
#
# Kolom: CashbackAmount
#   Shapiro-Wilk Test Statistic: 0.8896672788720152
#   Shapiro-Wilk p-value: 2.001124893567435e-43
# CashbackAmount tidak memiliki distribusi normal.

# %% [markdown]
# 3. persebaran distribusi antara fitur vs label

# %%
# Pastikan kolom Churn adalah integer
data_knn['Churn'] = data_knn['Churn'].astype(int)

cols = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']

plt.figure(figsize=(20, 30))

for i, col in enumerate(cols):
    plt.subplot(10, 4, i+1)
    sns.boxplot(data=data_knn, x='Churn', y=col, hue='Churn',
                palette={0: 'skyblue', 1: 'salmon'}, dodge=False, legend=False)
    plt.title(f'Boxplot {col} vs Churn')

plt.tight_layout()
plt.show()

# %% [markdown]
# kesimpulannya seluruh fitur tidak memiliki distribusi normal dan untuk distribusi label('Churn') tidak balace/imbalace

# %% [markdown]
# dan distribusi label vs fitur untuk persebarannya tidak merata itu ada tenure dan complain yang terlihat mudah dianalisis, terlihat customer yang churn rata rata pada pelanggan yang baru bergabung diantara 0 - 20an dan customer yang churn rata rata customer yang complain ,sedangkan yang persebarannya yang merata ada WarehouseToHome, NumberOfDeviceRegistered,nSatisfactionScore, NumberOfAddress, DaySinceLastOrder, CashbackAmount ini yang buduh analisis lebih dalam dikarenakan untuk mempersingkat waktu maka dibutuhkan machine learning

# %% [markdown]
# ### Outlier

# %%
data_o = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'DaySinceLastOrder',
       'CashbackAmount']

def check_outlier(data_knn, data_o):
    hasil_outlier = {}
    for col in data_o:
        q1 = data_knn[col].quantile(0.25)
        q3 = data_knn[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - (1.5 * iqr)
        upper_bound = q3 + (1.5 * iqr)
        outliers = data_knn[(data_knn[col] < lower_bound) | (data_knn[col] > upper_bound)]
        hasil_outlier[col] = {
            'jumlah_outliers' : outliers.shape[0],
            'Persentase Outlier': (outliers.shape[0] / data_knn.shape[0]) * 100
        }
    return pd.DataFrame(hasil_outlier).T
check_outlier(data_knn, data_o).sort_values(by='Persentase Outlier', ascending=False)
# Out:
#                           jumlah_outliers  Persentase Outlier
# CashbackAmount                      253.0            7.737003
# NumberOfDeviceRegistered            226.0            6.911315
# DaySinceLastOrder                     9.0            0.275229
# Tenure                                4.0            0.122324
# NumberOfAddress                       3.0            0.091743
# WarehouseToHome                       1.0            0.030581
# SatisfactionScore                     0.0            0.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 9))

for i, col in enumerate(data_o):
    plt.subplot(3, 3, i+1)
    sns.boxplot(x=data_knn[col], color='skyblue')
    plt.title(f'Boxplot {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Korelasi

# %% [markdown]
# - korelasi antara fitur dan label

# %%
data_knn.corr(method='spearman')['Churn'].sort_values(ascending=False)
# Out:
# Churn                       1.000000
# Complain                    0.262278
# NumberOfDeviceRegistered    0.104776
# SatisfactionScore           0.097100
# WarehouseToHome             0.078863
# NumberOfAddress             0.033872
# DaySinceLastOrder          -0.157666
# CashbackAmount             -0.170794
# Tenure                     -0.410056
# Name: Churn, dtype: float64

# %% [markdown]
# ## column kategorik yang akan di encode

# %%
import pandas as pd

data = pd.read_csv('data_ecommerce_customer_churn.csv')
data.columns
# Out:
# Index(['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
#        'PreferedOrderCat', 'SatisfactionScore', 'MaritalStatus',
#        'NumberOfAddress', 'Complain', 'DaySinceLastOrder', 'CashbackAmount',
#        'Churn'],
#       dtype='object')

# %%
data.select_dtypes(include='object').columns
# Out:
# Index(['PreferedOrderCat', 'MaritalStatus'], dtype='object')

# %%
data[['PreferedOrderCat', 'MaritalStatus']]
# Out:
#         PreferedOrderCat MaritalStatus
# 0     Laptop & Accessory        Single
# 1                 Mobile       Married
# 2     Laptop & Accessory       Married
# 3                Fashion      Divorced
# 4                 Others        Single
# ...                  ...           ...
# 3936             Fashion       Married
# 3937        Mobile Phone        Single
# 3938  Laptop & Accessory       Married
# 3939              Mobile       Married
# 3940  Laptop & Accessory       Married
#
# [3941 rows x 2 columns]

# %% [markdown]
# value keduanya tidak memiliki urutan

# %%
data[['PreferedOrderCat', 'MaritalStatus']].nunique()
# Out:
# PreferedOrderCat    6
# MaritalStatus       3
# dtype: int64

# %% [markdown]
# kesimpulannya menggunakan onehot encoding dikarenakan jumlah group <15 dan tidak memiliki urutan

# %% [markdown]
# ## column numerik yang akan di scaling

# %%
data.select_dtypes(include='number').describe()
# Out:
#             Tenure  WarehouseToHome  NumberOfDeviceRegistered  \
# count  3747.000000      3772.000000               3941.000000
# mean     10.081398        15.650583                  3.679269
# std       8.498864         8.452301                  1.013938
# min       0.000000         5.000000                  1.000000
# 25%       2.000000         9.000000                  3.000000
# 50%       9.000000        14.000000                  4.000000
# 75%      16.000000        21.000000                  4.000000
# max      61.000000       127.000000                  6.000000
#
#        SatisfactionScore  NumberOfAddress     Complain  DaySinceLastOrder  \
# count        3941.000000      3941.000000  3941.000000        3728.000000
# mean            3.088302         4.237757     0.282416           4.531652
# std             1.381832         2.626699     0.450232           3.667648
# min             1.000000         1.000000     0.000000           0.000000
# 25%             2.000000         2.000000     0.000000           2.000000
# 50%             3.000000         3.000000     0.000000           3.000000
# 75%             4.000000         6.000000     1.000000           7.000000
# max             5.000000        22.000000     1.000000          46.000000
#
#        CashbackAmount        Churn
# count     3941.000000  3941.000000
# mean       176.707419     0.171023
# std         48.791784     0.376576
# min          0.000000     0.000000
# 25%        145.700000     0.000000
# 50%        163.340000     0.000000
# 75%        195.250000     0.000000
# max        324.990000     1.000000

# %% [markdown]
# kesimpulannya yang akan di scaling hanya kolom CashbackAmout min:0 max:324.9 ini yang paling jauh scalanya dikarenakan CashbackAmout memiliki outlier upper dan lower yang lumayan banyak maka cocok memakai robust_scaler

# %% [markdown]
# ## Tipe masalah

# %%
data['Churn'].value_counts()
# Out:
# Churn
# 0    3267
# 1     674
# Name: count, dtype: int64

# %% [markdown]
# kita bisa simpulkan tipe masalahnya adalah Binary classification dikarenakan label adalah biner 0 dan 1, memiliki 2 kelas
#
# misal lebih dari > 2 kelas masuk ke Multiclass classification
#
# serta kelas 0 dan 1 tidak seimbang, diperlukannya balancing

# %% [markdown]
# ### Mencari best sampling imbalance menggunakan xg-boost

# %% [markdown]
# kenapa xg-boost karena lebih tahan terhadap outlier dan distribusi tidak normal sesuai eda dan xg-boost juga model yang paling efisien cara bekerjanya memperbaiki kesalahan di model sebelumnya

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from imblearn.pipeline import Pipeline
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, f1_score
from sklearn.impute import KNNImputer
from sklearn.model_selection import StratifiedKFold


data_ml = pd.read_csv('data_ml.csv')

# Pisahkan fitur dan target
X = data_ml.drop(['PreferedOrderCat', 'MaritalStatus', 'Churn'], axis=1)
y = data_ml['Churn']

# Buat model
model = XGBClassifier(random_state=42)

# Buat scorer (misal F1-score)
scorer = make_scorer(f1_score)

# RandomUnderSampler
pipe_under = Pipeline([
     ('imputer', KNNImputer(n_neighbors=5)),
    ('under', RandomUnderSampler(random_state=42)),
    ('clf', model)
])
score_under = cross_val_score(pipe_under, X, y, scoring=scorer, cv=5)
print("F1-score dengan RandomUnderSampler:", score_under.mean())

# SMOTE
pipe_smote = Pipeline([
     ('imputer', KNNImputer(n_neighbors=5)),
    ('smote', SMOTE(random_state=42)),
    ('clf', model)
])

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

score_smote = cross_val_score(pipe_smote, X, y, scoring=scorer, cv=cv)
print("F1-score dengan SMOTE:", score_smote.mean())

# TomekLinks
pipe_tomek = Pipeline([
     ('imputer', KNNImputer(n_neighbors=5)),
    ('tomek', TomekLinks(sampling_strategy='auto')),
    ('clf', model)
])
score_tomek = cross_val_score(pipe_tomek, X, y, scoring=scorer, cv=5)
print("F1-score dengan TomekLinks:", score_tomek.mean())
# Out:
# F1-score dengan RandomUnderSampler: 0.6308111212459039
# F1-score dengan SMOTE: 0.7390824352936857
# F1-score dengan TomekLinks: 0.6995555152009796

# %% [markdown]
# kesimpulannya menggunakan Oversampling : SMOTE lebih bagus f1-scorenya

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# disini saya akan menguji 6 model  sekaligus kenapa langsung 6 model campuran original, baging dan boosting supaya untuk mempercepat waktu pencarian model terbaik jadi langsung menguji 6 model sekaligus.
#
# type ke-6 model :
#
#
# **Original**
# - LogisticRegression
# - DecisionTreeClassifier
# - KNeighborsClassifier
#
# **Baging**
# - RandomForestClassifier
#
# **Boosting**
# - LGBMClassifier
# - XGBClassifier

# %% [markdown]
# kenapa saya mencoba semuanya padahal dari edanya kita melihat distribusi tidak normal, memiliki outlier harusnya ini cocok untuk model LGBMClassifier, RandomForestClassifier, XGBClassifier, DecisionTreeClassifier karena saya ingin menguji coba apakah model LogisticRegression, KNeighborsClassifier yang sesnsitif terhadap outlier walaupun sudah di scaling tapi pakah hasilnya bagus jadi itu alasan saya melakukannya walupun saya tahu ke2 model itu tidak maksimal beroperasi disaat data memiliki outlier dan distribusi tidak normal

# %% [markdown]
# ## 6 Model Dengan scaling

# %%
import pandas as pd
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from imblearn.over_sampling import SMOTE

data_ml = pd.read_csv('data_ml.csv')

# Pisahkan fitur dan target
X = data_ml.drop('Churn', axis=1)
y = data_ml['Churn']

# Split data jadi Train (80%) dan Test (20%) → Stratified
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=2020
)

# Split lagi TrainVal menjadi Training (60%) dan Validation (20%)
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=0.25, stratify=y_trainval, random_state=2020
) # 0.25 itu didapat dari 20% dibagi 80% (data training)

# pilih fitur yang akan di imputasi, encode dan scaling
imputasi = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']
encode = ['PreferedOrderCat', 'MaritalStatus']
scaling = ['CashbackAmount']


# Buat pipeline untuk masing-masing transformasi: imputasi, encoding, dan scaling
knn_imputer_transformer = Pipeline(steps=[
    ('knn_imputer', KNNImputer(n_neighbors=5))
])
onehot_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])
rb_scaling_transformer = Pipeline(steps=[
    ('rb_scaling', RobustScaler())
])


# Gabungkan semua transformasi ke dalam ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('knn_imputer', knn_imputer_transformer, imputasi),
    ('onehot', onehot_transformer, encode),
    ('rb_scaling', rb_scaling_transformer, scaling)
], remainder='passthrough')

## kandidat model
models = {
    'Logistic Regression': LogisticRegression(), # random_state tidak perlu untuk 'liblinear'
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'KNN': KNeighborsClassifier(),   # tidak perlu random_state
    'LGBM': LGBMClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'xgboost': XGBClassifier(random_state=42)
}

model_results = []

for name, model in models.items():
    # pipeline keseluruhan/final
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('classifier', model)
    ])

    pipeline.fit(X_train, y_train)
    y_val_pred = pipeline.predict(X_val)

    acc = accuracy_score(y_val, y_val_pred)
    rec = recall_score(y_val, y_val_pred)
    prec = precision_score(y_val, y_val_pred)
    f1 = f1_score(y_val, y_val_pred)

    model_results.append({
        'Model': name,
        'Accuracy': acc,
        'Recall': rec,
        'Precision': prec,
        'F1': f1
    })


# Tampilkan hasil perbandingan
results_df = pd.DataFrame(model_results)
result_df = results_df.sort_values(by='F1', ascending=False)
result_df
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [LightGBM] [Info] Number of positive: 1642, number of negative: 1642
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000391 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3161
# [LightGBM] [Info] Number of data points in the train set: 3284, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
#                  Model  Accuracy    Recall  Precision        F1
# 5              xgboost  0.906728  0.654206   0.744681  0.696517
# 3                 LGBM  0.903670  0.598131   0.761905  0.670157
# 4        Random Forest  0.899083  0.588785   0.741176  0.656250
# 1        Decision Tree  0.859327  0.635514   0.561983  0.596491
# 0  Logistic Regression  0.798165  0.728972   0.430939  0.541667
# 2                  KNN  0.764526  0.700935   0.380711  0.493421

# %% [markdown]
# ## 6 Model Tanpa scaling

# %%
import pandas as pd
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from imblearn.over_sampling import SMOTE

data_ml = pd.read_csv('data_ml.csv')

# Pisahkan fitur dan target
X = data_ml.drop('Churn', axis=1)
y = data_ml['Churn']

# Split data jadi Train (80%) dan Test (20%) → Stratified
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=2020
)

# Split lagi TrainVal menjadi Training (60%) dan Validation (20%)
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=0.25, stratify=y_trainval, random_state=2020
) # 0.25 itu didapat dari 20% dibagi 80% (data training)

# pilih fitur yang akan di imputasi, encode
imputasi = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']
encode = ['PreferedOrderCat', 'MaritalStatus']

# Buat pipeline untuk masing-masing transformasi: imputasi, encoding, dan scaling
knn_imputer_transformer = Pipeline(steps=[
    ('knn_imputer', KNNImputer(n_neighbors=5))
])
onehot_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])

# Gabungkan semua transformasi ke dalam ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('knn_imputer', knn_imputer_transformer, imputasi),
    ('onehot', onehot_transformer, encode),
], remainder='passthrough')

## kandidat model
models = {
    'Logistic Regression': LogisticRegression(), # random_state tidak perlu untuk 'liblinear'
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'KNN': KNeighborsClassifier(),   # tidak perlu random_state
    'LGBM': LGBMClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'xgboost': XGBClassifier(random_state=42)
}

model_results = []

for name, model in models.items():
    # pipeline keseluruhan/final
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('classifier', model)
    ])

    pipeline.fit(X_train, y_train)
    y_val_pred = pipeline.predict(X_val)

    acc = accuracy_score(y_val, y_val_pred)
    rec = recall_score(y_val, y_val_pred)
    prec = precision_score(y_val, y_val_pred)
    f1 = f1_score(y_val, y_val_pred)

    model_results.append({
        'Model': name,
        'Accuracy': acc,
        'Recall': rec,
        'Precision': prec,
        'F1': f1
    })


# Tampilkan hasil perbandingan
results_df = pd.DataFrame(model_results)
result_df = results_df.sort_values(by='F1', ascending=False)
result_df
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [LightGBM] [Info] Number of positive: 1642, number of negative: 1642
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000565 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2907
# [LightGBM] [Info] Number of data points in the train set: 3284, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
#                  Model  Accuracy    Recall  Precision        F1
# 3                 LGBM  0.905199  0.607477   0.764706  0.677083
# 5              xgboost  0.900612  0.607477   0.738636  0.666667
# 4        Random Forest  0.894495  0.551402   0.737500  0.631016
# 1        Decision Tree  0.857798  0.607477   0.560345  0.582960
# 0  Logistic Regression  0.798165  0.728972   0.430939  0.541667
# 2                  KNN  0.764526  0.700935   0.380711  0.493421

# %% [markdown]
# ## KESIMPULAN

# %% [markdown]
# ### Hasil metrik 6 Model dengan scaling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### hasil metrik 6 model tanpa scaling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# dan kita bisa simpulkan ternya benar bahwa logistik regression dan knn clasifier kurang maksimal beroperasi saat ada outlier dan distribusi tidak normal

# %% [markdown]
# saya menggunakan scaling terhadap feature yang memilki nilai tinggi yaitu CashbackAmout dan kenapa menggunakan robust scaling dikarenakan Column tersebut mempunyai banayak Outlier sekitar 8.01% dari jumlah keseluruhan

# %% [markdown]
# Hasil metrik dari 6 model, model dengan scaling berjalan lebih baik dari pada model tidak melakuakan scaling  maka xgboost dan LGBM akan dievaluasi bedasarkan accuracy,recall,precision,f1 tertinggi

# %% [markdown]
# kenapa Boosting (lgbm dan xgboost) lebih tinggi f1-scorenya :
# - Model ini membangun pohon keputusan secara bertahap, dan setiap langkah fokus memperbaiki kesalahan sebelumnya.
# - mampu menangani data non linear
# - tahan terhadap outlier
# -tahan terhadap data yang memiliki distribusi tidak normal

# %% [markdown]
# # EVALUASI BEST MODEL

# %% [markdown]
# ## Cross validasion Best Model LGBM DAN XGB

# %%
import pandas as pd
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import StratifiedKFold, cross_val_score

# Load data
data_ml = pd.read_csv('data_ml.csv')

# Pisahkan fitur dan target
X = data_ml.drop('Churn', axis=1)
y = data_ml['Churn']

# Split data jadi Train (80%) dan Test (20%) → Stratified
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=2020
)

# pilih fitur yang akan di imputasi, encode
imputasi = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']
encode = ['PreferedOrderCat', 'MaritalStatus']
scaling = ['CashbackAmount']

# Buat pipeline untuk masing-masing transformasi: imputasi, encoding, dan scaling
knn_imputer_transformer = Pipeline(steps=[
    ('knn_imputer', KNNImputer(n_neighbors=5))
])
onehot_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])
rb_scaling_transformer = Pipeline(steps=[
    ('rb_scaling', RobustScaler())
])

# Gabungkan semua transformasi ke dalam ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('knn_imputer', knn_imputer_transformer, imputasi),
    ('onehot', onehot_transformer, encode),
    ('rb_scaling', rb_scaling_transformer, scaling)
], remainder='passthrough')

## kandidat model
models = {
    'xgboost': XGBClassifier(random_state=42),
    'lightgbm': LGBMClassifier(random_state=42)
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
model_results = []

for name, model in models.items():
    # pipeline keseluruhan/final
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('classifier', model)
    ])

    f1_scores = cross_val_score(pipeline, X_train, y_train, scoring='f1', cv=cv, n_jobs=-1)

    model_results.append({
        'Model': name,
        'Fold-1': f1_scores[0],
        'Fold-2': f1_scores[1],
        'Fold-3': f1_scores[2],
        'Fold-4': f1_scores[3],
        'Fold-5': f1_scores[4],
        'Mean F1': f1_scores.mean(),
        'Std F1': f1_scores.std()

    })


result_df = pd.DataFrame(model_results).T
result_df
# Out:
#                 0         1
# Model     xgboost  lightgbm
# Fold-1   0.653846  0.710526
# Fold-2   0.608108  0.653061
# Fold-3   0.695652  0.731707
# Fold-4   0.701299     0.725
# Fold-5   0.708075     0.675
# Mean F1  0.673396  0.699059
# Std F1   0.037739  0.030216

# %% [markdown]
# ### kesimpulan Cross vaidation

# %% [markdown]
# MOdel LGBM lebih baik dari pada Model XGB bedasarkan kfoldnya Model LGBM meannya lebih tinggi dan stdnya lebih kecil(std semakin kecil tandanya lebih stabil) berarti model LGBM lebih stabil dibanding model XGB

# %% [markdown]
# ## Hyperparameter tuning best model

# %% [markdown]
# ### LGBMClassifier

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
from imblearn.pipeline import Pipeline



pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('classifier', LGBMClassifier(random_state=42))
    ])

lgbm_params = {
    'classifier__n_estimators': [100, 300, 500, 1000],
    'classifier__max_depth': [3, 5, 7],
    'classifier__learning_rate': [0.01, 0.1, 0.2],
    'classifier__subsample': [0.7, 0.8, 1.0],
    'classifier__colsample_bytree': [0.7, 0.8, 1.0]
}

lgbm_grid = GridSearchCV(
    estimator=pipeline,
    param_grid=lgbm_params,
    scoring='f1',
    cv=5,
    n_jobs=-1,
    verbose=1
)

lgbm_grid.fit(X_train, y_train)

print("Best parameters (LightGBM):", lgbm_grid.best_params_)
print("Best F1 Score:", lgbm_grid.best_score_)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [LightGBM] [Info] Number of positive: 2189, number of negative: 2189
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001488 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3358
# [LightGBM] [Info] Number of data points in the train set: 4378, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Best parameters (LightGBM): {'classifier__colsample_bytree': 0.8, 'classifier__learning_rate': 0.2, 'classifier__max_depth': 7, 'classifier__n_estimators': 500, 'classifier__subsample': 0.7}
# Best F1 Score: 0.7327374999009526

# %% [markdown]
# # FINAL MODEL LGBM

# %% [markdown]
# ## Modeling

# %%
import pandas as pd
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from lightgbm import LGBMClassifier
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from imblearn.over_sampling import SMOTE
import warnings

data_ml = pd.read_csv('data_ml.csv')

# Pisahkan fitur dan target
X = data_ml.drop('Churn', axis=1)
y = data_ml['Churn']

# Split data jadi Train (80%) dan Test (20%) → Stratified
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=2020
)

# pilih fitur yang akan di imputasi, encode
imputasi = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']
encode = ['PreferedOrderCat', 'MaritalStatus']
scaling = ['CashbackAmount']

# Buat pipeline untuk masing-masing transformasi: imputasi, encoding, dan scaling
knn_imputer_transformer = Pipeline(steps=[
    ('knn_imputer', KNNImputer(n_neighbors=5))
])
onehot_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])
rb_scaling_transformer = Pipeline(steps=[
    ('rb_scaling', RobustScaler())
])

# Gabungkan semua transformasi ke dalam ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('knn_imputer', knn_imputer_transformer, imputasi),
    ('onehot', onehot_transformer, encode),
    ('rb_scaling', rb_scaling_transformer, scaling)
], remainder='passthrough')

# pipeline keseluruhan/final
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('smote', SMOTE(random_state=42)),
    ('classifier',  LGBMClassifier(colsample_bytree=0.8, learning_rate=0.2, max_depth=7, n_estimators=500, subsample=0.7, random_state=42))
])

pipeline.fit(X_train, y_train)
warnings.filterwarnings("ignore", category=UserWarning)

y_test_pred = pipeline.predict(X_test)

# Hitung metrik
acc = accuracy_score(y_test, y_test_pred)
rec = recall_score(y_test, y_test_pred)
prec = precision_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)

# Buat DataFrame hasil evaluasi
test_eval_df = pd.DataFrame([{
    'Model': 'LGBMClassifier test',
    'Accuracy': acc,
    'Recall': rec,
    'Precision': prec,
    'F1 Score': f1,

}])

test_eval_df
# Out:
# [LightGBM] [Info] Number of positive: 2189, number of negative: 2189
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001470 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3358
# [LightGBM] [Info] Number of data points in the train set: 4378, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                  Model  Accuracy   Recall  Precision  F1 Score
# 0  LGBMClassifier test  0.920489  0.71028   0.783505  0.745098

# %% [markdown]
# ## Evaluasi Confusion Matrix

# %%
from sklearn.metrics import recall_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# (Opsional) Confusion Matrix
cm = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Churn', 'Churn'], yticklabels=['Not Churn', 'Churn'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test, pipeline.predict_proba(X_test)[:, 1])
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Feature Importance

# %%
import pandas as pd

feature_names = pipeline.named_steps['preprocessor'].get_feature_names_out()

# Ambil importance dari model
importances = pipeline.named_steps['classifier'].feature_importances_


# Buat DataFrame importance
importance_df = pd.DataFrame({
    'Fitur': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

importance_df['NormalizedImportance'] = importance_df['Importance'] / importance_df['Importance'].sum()
importance_df.drop(columns=['Importance'], inplace=True)

importance_df
# Out:
#                                           Fitur  NormalizedImportance
# 7                   knn_imputer__CashbackAmount              0.188897
# 1                  knn_imputer__WarehouseToHome              0.173096
# 15                   rb_scaling__CashbackAmount              0.114093
# 0                           knn_imputer__Tenure              0.105979
# 6                knn_imputer__DaySinceLastOrder              0.095872
# 3                knn_imputer__SatisfactionScore              0.085623
# 4                  knn_imputer__NumberOfAddress              0.077153
# 2         knn_imputer__NumberOfDeviceRegistered              0.045125
# 5                         knn_imputer__Complain              0.032384
# 14                 onehot__MaritalStatus_Single              0.026263
# 9   onehot__PreferedOrderCat_Laptop & Accessory              0.021922
# 13                onehot__MaritalStatus_Married              0.016370
# 11        onehot__PreferedOrderCat_Mobile Phone              0.008826
# 10              onehot__PreferedOrderCat_Mobile              0.004840
# 12              onehot__PreferedOrderCat_Others              0.001993
# 8              onehot__PreferedOrderCat_Grocery              0.001566

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
ax = sns.barplot(x='NormalizedImportance', y='Fitur', data=importance_df)

for p in ax.patches:
    x = p.get_width()  # Posisi X di akhir bar
    y = p.get_y() + p.get_height() / 2  # Posisi Y di tengah bar
    ax.text(x + 0.0102, y, f'{x:.3f}', va='center', fontsize=10, ha='right')

plt.title('Feature Importance')
plt.show()

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# Dikarenakan hasilnya masih dibawah standatr yaitu recall, precision, f1-scorenya masih dibwah 8 scorenya, saya mencoba menambahkan data yang saya dapat dari kagle dengan column yang sama,kenapa columnnya harus sama  karena misal tidak sama columnya bisa merusak performa model

# %% [markdown]
# # PENAMBAHAN DATA EXTERNAL

# %% [markdown]
# ## Load data

# %% [markdown]
# ### data external dari Kagle

# %%
import pandas as pd

data3 = pd.read_excel('data3.xlsx')
data3
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0        4.0              6.0                         3  Laptop & Accessory
# 1        NaN              8.0                         4              Mobile
# 2        NaN             30.0                         4              Mobile
# 3        0.0             15.0                         4  Laptop & Accessory
# 4        0.0             12.0                         3              Mobile
# ...      ...              ...                       ...                 ...
# 5625    10.0             30.0                         2  Laptop & Accessory
# 5626    13.0             13.0                         5             Fashion
# 5627     1.0             11.0                         2  Laptop & Accessory
# 5628    23.0              9.0                         5  Laptop & Accessory
# 5629     8.0             15.0                         2  Laptop & Accessory
#
#       SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                     2        Single                9         1
# 1                     3        Single                7         1
# 2                     3        Single                6         1
# 3                     5        Single                8         0
# 4                     5        Single                3         0
# ...                 ...           ...              ...       ...
# 5625                  1       Married                6         0
# 5626                  5       Married                6         0
# 5627                  4       Married                3         1
# 5628                  4       Married                4         0
# 5629                  3       Married                4         0
#
#       DaySinceLastOrder  CashbackAmount  Churn
# 0                   5.0          159.93      1
# 1                   0.0          120.90      1
# 2                   3.0          120.28      1
# 3                   3.0          134.07      1
# 4                   3.0          129.60      1
# ...                 ...             ...    ...
# 5625                4.0          150.71      0
# 5626                NaN          224.91      0
# 5627                4.0          186.42      0
# 5628                9.0          178.90      0
# 5629                3.0          169.04      0
#
# [5630 rows x 11 columns]

# %% [markdown]
# ### data originalnya

# %%
data1 = pd.read_csv('data_ecommerce_customer_churn.csv')
data1
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0       15.0             29.0                         4  Laptop & Accessory
# 1        7.0             25.0                         4              Mobile
# 2       27.0             13.0                         3  Laptop & Accessory
# 3       20.0             25.0                         4             Fashion
# 4       30.0             15.0                         4              Others
# ...      ...              ...                       ...                 ...
# 3936    28.0              9.0                         5             Fashion
# 3937     8.0              7.0                         2        Mobile Phone
# 3938    30.0              6.0                         5  Laptop & Accessory
# 3939     6.0              NaN                         4              Mobile
# 3940     2.0              7.0                         3  Laptop & Accessory
#
#       SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                     3        Single                2         0
# 1                     1       Married                2         0
# 2                     1       Married                5         0
# 3                     3      Divorced                7         0
# 4                     4        Single                8         0
# ...                 ...           ...              ...       ...
# 3936                  3       Married                8         0
# 3937                  2        Single                4         0
# 3938                  3       Married                3         1
# 3939                  3       Married               10         1
# 3940                  5       Married                1         0
#
#       DaySinceLastOrder  CashbackAmount  Churn
# 0                   7.0          143.32      0
# 1                   7.0          129.29      0
# 2                   7.0          168.54      0
# 3                   NaN          230.27      0
# 4                   8.0          322.17      0
# ...                 ...             ...    ...
# 3936                1.0          231.86      0
# 3937                4.0          157.80      0
# 3938                2.0          156.60      0
# 3939                0.0          124.37      1
# 3940                2.0          153.73      0
#
# [3941 rows x 11 columns]

# %% [markdown]
# ## menggabungkan kedua data

# %%
data_ecomerce = pd.concat([data1, data3], axis=0, ignore_index=True)
data_ecomerce
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0       15.0             29.0                         4  Laptop & Accessory
# 1        7.0             25.0                         4              Mobile
# 2       27.0             13.0                         3  Laptop & Accessory
# 3       20.0             25.0                         4             Fashion
# 4       30.0             15.0                         4              Others
# ...      ...              ...                       ...                 ...
# 9566    10.0             30.0                         2  Laptop & Accessory
# 9567    13.0             13.0                         5             Fashion
# 9568     1.0             11.0                         2  Laptop & Accessory
# 9569    23.0              9.0                         5  Laptop & Accessory
# 9570     8.0             15.0                         2  Laptop & Accessory
#
#       SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                     3        Single                2         0
# 1                     1       Married                2         0
# 2                     1       Married                5         0
# 3                     3      Divorced                7         0
# 4                     4        Single                8         0
# ...                 ...           ...              ...       ...
# 9566                  1       Married                6         0
# 9567                  5       Married                6         0
# 9568                  4       Married                3         1
# 9569                  4       Married                4         0
# 9570                  3       Married                4         0
#
#       DaySinceLastOrder  CashbackAmount  Churn
# 0                   7.0          143.32      0
# 1                   7.0          129.29      0
# 2                   7.0          168.54      0
# 3                   NaN          230.27      0
# 4                   8.0          322.17      0
# ...                 ...             ...    ...
# 9566                4.0          150.71      0
# 9567                NaN          224.91      0
# 9568                4.0          186.42      0
# 9569                9.0          178.90      0
# 9570                3.0          169.04      0
#
# [9571 rows x 11 columns]

# %% [markdown]
# ## save data

# %%
data_ecomerce.to_csv('data_ecomerce.csv', index=False)

# %% [markdown]
# save data untuk data preparation

# %% [markdown]
# ## DATA PREPARATION (gabungan ke 2 data)

# %%
import pandas as pd

data_ecomerce = pd.read_csv('data_ecomerce.csv')
data_ecomerce
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0       15.0             29.0                         4  Laptop & Accessory
# 1        7.0             25.0                         4              Mobile
# 2       27.0             13.0                         3  Laptop & Accessory
# 3       20.0             25.0                         4             Fashion
# 4       30.0             15.0                         4              Others
# ...      ...              ...                       ...                 ...
# 9566    10.0             30.0                         2  Laptop & Accessory
# 9567    13.0             13.0                         5             Fashion
# 9568     1.0             11.0                         2  Laptop & Accessory
# 9569    23.0              9.0                         5  Laptop & Accessory
# 9570     8.0             15.0                         2  Laptop & Accessory
#
#       SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                     3        Single                2         0
# 1                     1       Married                2         0
# 2                     1       Married                5         0
# 3                     3      Divorced                7         0
# 4                     4        Single                8         0
# ...                 ...           ...              ...       ...
# 9566                  1       Married                6         0
# 9567                  5       Married                6         0
# 9568                  4       Married                3         1
# 9569                  4       Married                4         0
# 9570                  3       Married                4         0
#
#       DaySinceLastOrder  CashbackAmount  Churn
# 0                   7.0          143.32      0
# 1                   7.0          129.29      0
# 2                   7.0          168.54      0
# 3                   NaN          230.27      0
# 4                   8.0          322.17      0
# ...                 ...             ...    ...
# 9566                4.0          150.71      0
# 9567                NaN          224.91      0
# 9568                4.0          186.42      0
# 9569                9.0          178.90      0
# 9570                3.0          169.04      0
#
# [9571 rows x 11 columns]

# %% [markdown]
# ### duplikat

# %%
data_ecomerce.duplicated().sum()
# Out:
# np.int64(5241)

# %%
data_ecomerce.drop_duplicates(inplace=True)
data_ecomerce.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_ecomerce.reset_index(drop=True, inplace=True)
data_ecomerce
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0       15.0             29.0                         4  Laptop & Accessory
# 1        7.0             25.0                         4              Mobile
# 2       27.0             13.0                         3  Laptop & Accessory
# 3       20.0             25.0                         4             Fashion
# 4       30.0             15.0                         4              Others
# ...      ...              ...                       ...                 ...
# 4325     7.0              8.0                         5        Mobile Phone
# 4326    12.0              8.0                         4  Laptop & Accessory
# 4327     7.0             22.0                         4  Laptop & Accessory
# 4328    30.0              8.0                         4  Laptop & Accessory
# 4329    14.0              8.0                         4  Laptop & Accessory
#
#       SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                     3        Single                2         0
# 1                     1       Married                2         0
# 2                     1       Married                5         0
# 3                     3      Divorced                7         0
# 4                     4        Single                8         0
# ...                 ...           ...              ...       ...
# 4325                  3       Married                3         0
# 4326                  4       Married                2         0
# 4327                  1       Married                2         1
# 4328                  3       Married                3         0
# 4329                  3       Married                9         0
#
#       DaySinceLastOrder  CashbackAmount  Churn
# 0                   7.0          143.32      0
# 1                   7.0          129.29      0
# 2                   7.0          168.54      0
# 3                   NaN          230.27      0
# 4                   8.0          322.17      0
# ...                 ...             ...    ...
# 4325                1.0          145.08      0
# 4326                9.0          169.40      0
# 4327                2.0          173.78      0
# 4328               10.0          188.06      0
# 4329                2.0          192.28      1
#
# [4330 rows x 11 columns]

# %% [markdown]
# ### cek missing value

# %%
missing_value = data_ecomerce.isna().sum().reset_index(name='Jumlah Missing Value')
missing_value['persentase'] = round(missing_value['Jumlah Missing Value'] / len(data_ecomerce) * 100, 2)
missing_value.sort_values(by='persentase', ascending=False).head(5)
# Out:
#                       index  Jumlah Missing Value  persentase
# 8         DaySinceLastOrder                   243        5.61
# 0                    Tenure                   195        4.50
# 1           WarehouseToHome                   183        4.23
# 2  NumberOfDeviceRegistered                     0        0.00
# 3          PreferedOrderCat                     0        0.00

# %% [markdown]
# ### Save data

# %%
data_ecomerce.to_csv('data_final.csv', index=False)

# %% [markdown]
# save data untuk menerapkan di machine learning yang sudah tidak mengandung dulikat

# %% [markdown]
# # MACHINE LEANING FINAL (6 MODEL )

# %% [markdown]
# ## modeling dengan scaling dikarenakan dengan scaling lebih baik

# %%
import pandas as pd
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from imblearn.over_sampling import SMOTE

data_ml = pd.read_csv('data_final.csv')

# Pisahkan fitur dan target
X = data_ml.drop('Churn', axis=1)
y = data_ml['Churn']

# Split data jadi Train (80%) dan Test (20%) → Stratified
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=2020
)

# Split lagi TrainVal menjadi Training (60%) dan Validation (20%)
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=0.25, stratify=y_trainval, random_state=2020
) # 0.25 itu didapat dari 20% dibagi 80% (data training)

# pilih fitur yang akan di imputasi, encode dan scaling
imputasi = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']
encode = ['PreferedOrderCat', 'MaritalStatus']
scaling = ['CashbackAmount']


# Buat pipeline untuk masing-masing transformasi: imputasi, encoding, dan scaling
knn_imputer_transformer = Pipeline(steps=[
    ('knn_imputer', KNNImputer(n_neighbors=5))
])
onehot_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])
rb_scaling_transformer = Pipeline(steps=[
    ('rb_scaling', RobustScaler())
])


# Gabungkan semua transformasi ke dalam ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('knn_imputer', knn_imputer_transformer, imputasi),
    ('onehot', onehot_transformer, encode),
    ('rb_scaling', rb_scaling_transformer, scaling)
], remainder='passthrough')

## kandidat model
models = {
    'Logistic Regression': LogisticRegression(), # random_state tidak perlu untuk 'liblinear'
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'KNN': KNeighborsClassifier(),   # tidak perlu random_state
    'LGBM': LGBMClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'xgboost': XGBClassifier(random_state=42)
}

model_results = []

for name, model in models.items():
    # pipeline keseluruhan/final
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('classifier', model)
    ])

    pipeline.fit(X_train, y_train)
    y_val_pred = pipeline.predict(X_val)

    acc = accuracy_score(y_val, y_val_pred)
    rec = recall_score(y_val, y_val_pred)
    prec = precision_score(y_val, y_val_pred)
    f1 = f1_score(y_val, y_val_pred)

    model_results.append({
        'Model': name,
        'Accuracy': acc,
        'Recall': rec,
        'Precision': prec,
        'F1': f1
    })


# Tampilkan hasil perbandingan
results_df = pd.DataFrame(model_results)
result_df = results_df.sort_values(by='F1', ascending=False)
result_df
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [LightGBM] [Info] Number of positive: 2194, number of negative: 2194
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000926 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3358
# [LightGBM] [Info] Number of data points in the train set: 4388, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
#                  Model  Accuracy    Recall  Precision        F1
# 5              xgboost  0.934180  0.723881   0.829060  0.772908
# 3                 LGBM  0.924942  0.708955   0.785124  0.745098
# 4        Random Forest  0.916859  0.641791   0.781818  0.704918
# 1        Decision Tree  0.882217  0.649254   0.612676  0.630435
# 0  Logistic Regression  0.769053  0.828358   0.385417  0.526066
# 2                  KNN  0.770208  0.768657   0.380074  0.508642

# %% [markdown]
# ## Evaluasi best model best model XGB dan LGBM

# %% [markdown]
# ### cross validation

# %%
import pandas as pd
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import StratifiedKFold, cross_val_score

# Load data
data_ml = pd.read_csv('data_final.csv')

# Pisahkan fitur dan target
X = data_ml.drop('Churn', axis=1)
y = data_ml['Churn']

# Split data jadi Train (80%) dan Test (20%) → Stratified
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=2020
)

# pilih fitur yang akan di imputasi, encode
imputasi = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']
encode = ['PreferedOrderCat', 'MaritalStatus']
scaling = ['CashbackAmount']

# Buat pipeline untuk masing-masing transformasi: imputasi, encoding, dan scaling
knn_imputer_transformer = Pipeline(steps=[
    ('knn_imputer', KNNImputer(n_neighbors=5))
])
onehot_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])
rb_scaling_transformer = Pipeline(steps=[
    ('rb_scaling', RobustScaler())
])

# Gabungkan semua transformasi ke dalam ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('knn_imputer', knn_imputer_transformer, imputasi),
    ('onehot', onehot_transformer, encode),
    ('rb_scaling', rb_scaling_transformer, scaling)
], remainder='passthrough')

## kandidat model
models = {
    'xgboost': XGBClassifier(random_state=42),
    'lightgbm': LGBMClassifier(random_state=42)
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
model_results = []

for name, model in models.items():
    # pipeline keseluruhan/final
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('classifier', model)
    ])

    f1_scores = cross_val_score(pipeline, X_train, y_train, scoring='f1', cv=cv, n_jobs=-1)

    model_results.append({
        'Model': name,
        'Fold-1': f1_scores[0],
        'Fold-2': f1_scores[1],
        'Fold-3': f1_scores[2],
        'Fold-4': f1_scores[3],
        'Fold-5': f1_scores[4],
        'Mean F1': f1_scores.mean(),
        'Std F1': f1_scores.std()

    })


result_df = pd.DataFrame(model_results).T
result_df
# Out:
#                 0         1
# Model     xgboost  lightgbm
# Fold-1    0.76699  0.742574
# Fold-2   0.755981  0.735849
# Fold-3   0.757576  0.736842
# Fold-4    0.76555  0.730964
# Fold-5   0.760976      0.73
# Mean F1  0.761415  0.735246
# Std F1   0.004305  0.004527

# %% [markdown]
# ### Hyperparameter tuning best model

# %% [markdown]
# #### XGB

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from imblearn.pipeline import Pipeline

pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('classifier',XGBClassifier(random_state=42))
    ])

# Parameter grid untuk XGBoost
param_grid = {
    'classifier__n_estimators': [100, 300, 500, 1000],
    'classifier__max_depth': [3, 5, 7],
    'classifier__learning_rate': [0.01, 0.1, 0.2],
    'classifier__subsample': [0.7, 0.8, 1.0],
    'classifier__colsample_bytree': [0.7, 0.8, 1.0]
}

# GridSearchCV
grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring='f1',
    cv=5,
    n_jobs=-1,
    verbose=1
)

# Latih model
grid_search.fit(X_train, y_train)

# Tampilkan hasil terbaik
print("Best parameters (XGBoost):", grid_search.best_params_)
print("Best F1 Score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best parameters (XGBoost): {'classifier__colsample_bytree': 0.7, 'classifier__learning_rate': 0.1, 'classifier__max_depth': 7, 'classifier__n_estimators': 1000, 'classifier__subsample': 1.0}
# Best F1 Score: 0.8116861077028213

# %% [markdown]
# #### LGBM

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
from imblearn.pipeline import Pipeline



pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('classifier', LGBMClassifier(random_state=42))
    ])

lgbm_params = {
    'classifier__n_estimators': [100, 300, 500, 1000],
    'classifier__max_depth': [3, 5, 7],
    'classifier__learning_rate': [0.01, 0.1, 0.2],
    'classifier__subsample': [0.7, 0.8, 1.0],
    'classifier__colsample_bytree': [0.7, 0.8, 1.0]
}

lgbm_grid = GridSearchCV(
    estimator=pipeline,
    param_grid=lgbm_params,
    scoring='f1',
    cv=5,
    n_jobs=-1,
    verbose=1
)

lgbm_grid.fit(X_train, y_train)

print("Best parameters (LightGBM):", lgbm_grid.best_params_)
print("Best F1 Score:", lgbm_grid.best_score_)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [LightGBM] [Info] Number of positive: 2926, number of negative: 2926
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001476 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3351
# [LightGBM] [Info] Number of data points in the train set: 5852, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Best parameters (LightGBM): {'classifier__colsample_bytree': 0.7, 'classifier__learning_rate': 0.2, 'classifier__max_depth': 7, 'classifier__n_estimators': 1000, 'classifier__subsample': 0.7}
# Best F1 Score: 0.8125465681862094

# %% [markdown]
# # MACHINE LEARNING FINAL BEST MODEL

# %% [markdown]
# ## modeling

# %% [markdown]
# ### model XGB (hyperparameter tuning dengan data gabungan)

# %%
import pandas as pd
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from xgboost import XGBClassifier
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from imblearn.over_sampling import SMOTE
import warnings

data_ml = pd.read_csv('data_final.csv')

# Pisahkan fitur dan target
X = data_ml.drop('Churn', axis=1)
y = data_ml['Churn']

# Split data jadi Train (80%) dan Test (20%) → Stratified
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# pilih fitur yang akan di imputasi, encode
imputasi = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']
encode = ['PreferedOrderCat', 'MaritalStatus']
scaling = ['CashbackAmount']

# Buat pipeline untuk masing-masing transformasi: imputasi, encoding, dan scaling
knn_imputer_transformer = Pipeline(steps=[
    ('knn_imputer', KNNImputer(n_neighbors=5))
])
onehot_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])
rb_scaling_transformer = Pipeline(steps=[
    ('rb_scaling', RobustScaler())
])

# Gabungkan semua transformasi ke dalam ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('knn_imputer', knn_imputer_transformer, imputasi),
    ('onehot', onehot_transformer, encode),
    ('rb_scaling', rb_scaling_transformer, scaling)
], remainder='passthrough')

# pipeline keseluruhan/final
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('smote', SMOTE(random_state=42)),
    ('classifier', XGBClassifier(colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=1000, subsample=1.0, random_state=42))
])

# latih datanya
pipeline.fit(X_train, y_train)

#untuk mengilangkan warning
warnings.filterwarnings("ignore", category=UserWarning)

#predict data yang sudah di latih
y_test_pred = pipeline.predict(X_test)

# Hitung metrik
acc = accuracy_score(y_test, y_test_pred)
rec = recall_score(y_test, y_test_pred)
prec = precision_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)

# Buat DataFrame hasil evaluasi
test_eval_df = pd.DataFrame([{
    'Model': 'XGBClassifier test',
    'Accuracy': acc,
    'Recall': rec,
    'Precision': prec,
    'F1 Score': f1,

}])

test_eval_df
# Out:
#                 Model  Accuracy    Recall  Precision  F1 Score
# 0  XGBClassifier test   0.93418  0.748148   0.814516  0.779923

# %% [markdown]
# ### model LGBM (hyperparameter tuning dengan data gabungan)

# %%
import pandas as pd
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from lightgbm import LGBMClassifier
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from imblearn.over_sampling import SMOTE
import warnings

data_ml = pd.read_csv('data_final.csv')

# Pisahkan fitur dan target
X = data_ml.drop('Churn', axis=1)
y = data_ml['Churn']

# Split data jadi Train (80%) dan Test (20%) → Stratified
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# pilih fitur yang akan di imputasi, encode
imputasi = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']
encode = ['PreferedOrderCat', 'MaritalStatus']
scaling = ['CashbackAmount']

# Buat pipeline untuk masing-masing transformasi: imputasi, encoding, dan scaling
knn_imputer_transformer = Pipeline(steps=[
    ('knn_imputer', KNNImputer(n_neighbors=5))
])
onehot_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])
rb_scaling_transformer = Pipeline(steps=[
    ('rb_scaling', RobustScaler())
])

# Gabungkan semua transformasi ke dalam ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('knn_imputer', knn_imputer_transformer, imputasi),
    ('onehot', onehot_transformer, encode),
    ('rb_scaling', rb_scaling_transformer, scaling)
], remainder='passthrough')

# pipeline keseluruhan/final
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('smote', SMOTE(random_state=42)),
    ('classifier', LGBMClassifier(colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=1000, subsample=0.7, random_state=42))
])

# latih datanya
pipeline.fit(X_train, y_train)

#untuk mengilangkan warning
warnings.filterwarnings("ignore", category=UserWarning)

#predict data yang sudah di latih
y_test_pred = pipeline.predict(X_test)

# Hitung metrik
acc = accuracy_score(y_test, y_test_pred)
rec = recall_score(y_test, y_test_pred)
prec = precision_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)

# Buat DataFrame hasil evaluasi
test_eval_df = pd.DataFrame([{
    'Model': 'LGBMClassifier test',
    'Accuracy': acc,
    'Recall': rec,
    'Precision': prec,
    'F1 Score': f1,

}])

test_eval_df
# Out:
# [LightGBM] [Info] Number of positive: 2926, number of negative: 2926
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002137 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3365
# [LightGBM] [Info] Number of data points in the train set: 5852, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                  Model  Accuracy    Recall  Precision  F1 Score
# 0  LGBMClassifier test  0.938799  0.777778   0.820312  0.798479

# %% [markdown]
# ### model LGBM (hyperparameter tuning dengan data original)

# %% [markdown]
# - install scikit-learn dan imblanced-learn terbaru untuk upload ke streamlit karena harus sama versinya

# %%
pip install -U scikit-learn==1.7.1
# Out:
# Collecting scikit-learn==1.7.1
#   Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.7.1) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.7.1) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.7.1) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.7.1) (3.6.0)
# Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 84.9 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.1 which is incompatible.
# Successfully installed scikit-learn-1.7.1

# %%
pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.14.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.16.1)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.7.1)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (3.6.0)
# Downloading imbalanced_learn-0.14.0-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.0/240.0 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.13.0
#     Uninstalling imbalanced-learn-0.13.0:
#       Successfully uninstalled imbalanced-learn-0.13.0
# Successfully installed imbalanced-learn-0.14.0

# %%
import pandas as pd
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from lightgbm import LGBMClassifier
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from imblearn.over_sampling import SMOTE
import warnings

data_ml = pd.read_csv('data_final.csv')

# Pisahkan fitur dan target
X = data_ml.drop('Churn', axis=1)
y = data_ml['Churn']

# Split data jadi Train (80%) dan Test (20%) → Stratified
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# pilih fitur yang akan di imputasi, encode
imputasi = ['Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered',
       'SatisfactionScore', 'NumberOfAddress', 'Complain', 'DaySinceLastOrder',
       'CashbackAmount']
encode = ['PreferedOrderCat', 'MaritalStatus']
scaling = ['CashbackAmount']

# Buat pipeline untuk masing-masing transformasi: imputasi, encoding, dan scaling
knn_imputer_transformer = Pipeline(steps=[
    ('knn_imputer', KNNImputer(n_neighbors=5))
])
onehot_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])
rb_scaling_transformer = Pipeline(steps=[
    ('rb_scaling', RobustScaler())
])

# Gabungkan semua transformasi ke dalam ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('knn_imputer', knn_imputer_transformer, imputasi),
    ('onehot', onehot_transformer, encode),
    ('rb_scaling', rb_scaling_transformer, scaling)
], remainder='passthrough')

# pipeline keseluruhan/final
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('smote', SMOTE(random_state=42)),
    ('classifier',   LGBMClassifier(colsample_bytree=0.8, learning_rate=0.2, max_depth=7, n_estimators=500, subsample=0.7, random_state=42))
])

# latih datanya
pipeline.fit(X_train, y_train)

#untuk mengilangkan warning
warnings.filterwarnings("ignore", category=UserWarning)

#predict data yang sudah di latih
y_test_pred = pipeline.predict(X_test)

# Hitung metrik
acc = accuracy_score(y_test, y_test_pred)
rec = recall_score(y_test, y_test_pred)
prec = precision_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)

# Buat DataFrame hasil evaluasi
test_eval_df = pd.DataFrame([{
    'Model': 'LGBMClassifier test',
    'Accuracy': acc,
    'Recall': rec,
    'Precision': prec,
    'F1 Score': f1,

}])

test_eval_df
# Out:
# [LightGBM] [Info] Number of positive: 2926, number of negative: 2926
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000816 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3365
# [LightGBM] [Info] Number of data points in the train set: 5852, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                  Model  Accuracy    Recall  Precision  F1 Score
# 0  LGBMClassifier test  0.943418  0.785185    0.84127  0.812261

# %% [markdown]
# ### Kesimpulan 2 model dengan hyperparameter tuning berbeda

# %% [markdown]
# - model XGB (hyperparameter tuning dengan data gabungan)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - model LGBM (hyperparameter tuning dengan data gabungan)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - model LGBM (hyperparameter tuning dengan data original)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# kesimpulannya model LGBM (hyperparameter tuning dengan data original) lebih tinggi score metriknya

# %% [markdown]
# ## Evaluasi model LGBM (hyperparameter tuning dengan data original)

# %% [markdown]
# ### Evaluasi Hasil metrik

# %%
test_eval_df
# Out:
#                  Model  Accuracy    Recall  Precision  F1 Score
# 0  LGBMClassifier test  0.943418  0.785185    0.84127  0.812261

# %% [markdown]
# dari hasil metrk diatas kita bisa simpulkan :
#
# - Jika biaya kehilangan pelanggan lebih besar, maka Recall menjadi prioritas utama
#
# - Jika biaya untuk mempertahankan pelanggan lebih besar, maka Precision menjadi prioritas utama
#
# - Jika ingin keseimbangan, maka F1-score digunakan sebagai metrik utama, F1-score memberikan keseimbangan antara Recall dan Precision, sehingga menjadi solusi tengah:
#
#     - Tidak terlalu banyak pelanggan yang lolos (Recall dijaga)
#
#     - Tidak terlalu banyak pelanggan yang salah sasaran (Precision tetap diperhatikan)

# %% [markdown]
# ### Evaluasi Confusion Matrix

# %%
from sklearn.metrics import recall_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# (Opsional) Confusion Matrix
cm = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Churn', 'Churn'], yticklabels=['Not Churn', 'Churn'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# dari grafik diatas kita bisa simpulkan
#
#
#
# *   0 : 0 = 711, ada sebanyak 711 yang aktualnya not churn prediksinya not churn
# *   0 : 1 = 20, ada sebanyak 20 yang aktualnya not churn tapi prediksinya churn
# *   1 : 0 = 29, ada sebanyak 29 pelanggan yang aktualnya churn tapi prediksinya not churn
# *   1 : 1 = 106, ada sebanyak 106 pelanggan yang aktualnya churn prediksinya churn
#
#
# kesimpulan akhir :
# 1. ada sebanyak 20 pelanggan yang dianggap not churn tapi churn dan ini bisa menyebabkan kerugian dikarenakan misal perusahaan ingin memberikan promosi terhadap pelanggan yang churn tapi malah salah promosi kepada pelanggan yang tidak churn
# 2. ada sebanyak 29 pelanggan yang sebenarnya churn tapi not churn, dan ini bisa menyebabkan kerugian terhadap pendapatan karena pelanggan yang berlanggan biasanya PO(preorder) nya cepat dibanding yang berlanggan

# %% [markdown]
# Estimasi kerugian :
#
#   1. fokus recall  TP(106) / (TP(106)+FN(29)) = 0.78
#     - misal biaya kehilangan pelanggan 1jt
#     - model tidak mendeteksi pelanggan churn sebanyak 0.22|29
#     - estimasi kerugian : 1jt x 29 = 29jt
#   2. fokus ke precision TP(106) / (TP(106)+FP(20)) = 0.84
#     - misal biaya promosi salah sasaran 1jt
#     - model salah prediksi pelangan churn aktualnya not churn sebanyak 0.16|20
#     - maka estimasi kerugian : 1jt x 20 = 20jt
#   3. fokus ke f1 score  (2 x (P x R)) / (P + R ) = 0.81
#     - estimasi kerugian : R(29jt) + P(20jt) = 49jt, ini adalah estimasi kerugian jika ingin memperthankan keduannya
#     - kekurangannya bisa membakar uang lebih banyak
#     - kelebihannya mempertahankan pelanggan yang churn dan ada potensi pelanggan baru yang churn karena promosi tersebar lebih luas

# %% [markdown]
# ### Evaluasi ROC Curve

# %% [markdown]
# ini evaluasi tambahan untuk melihat seberapa baik model memebedakan kelas di berbagai threshold

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, pipeline.predict_proba(X_test)[:, 1])
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

# Tambahkan threshold pada beberapa titik
for i in range(0, len(thresholds), int(len(thresholds)/10)):
    plt.annotate(f'{thresholds[i]:.2f}', (fpr[i], tpr[i]), fontsize=8)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# dari grafik diatas
#
#
# *   saat hasil prediksi tru positif garis orange/roc curve nya pada TPR 0.8 model berhasil menangkap 80% dari kelas positif (misalnya pelanggan yang benar-benar churn). Namun, saat itu model juga mulai menghasilkan false positive, yaitu memprediksi “churn” padahal sebenarnya tidak churn (kelas negatif).
# *   untuk roc curve area / AUC nya adalah 0.95 berarti model sudah baik dalam membedakan pelanggan yang churn dan not churn
# *   Threshold 0.62 dapat dianggap sebagai titik ambang yang cukup seimbang untuk menentukan apakah seorang pelanggan diklasifikasikan sebagai churn atau tidak.
# Jika kita ingin fokus pada recall (misalnya untuk memastikan semua pelanggan yang berisiko churn bisa terdeteksi), maka threshold bisa diturunkan. Namun, konsekuensinya adalah precision akan menurun karena semakin banyak false positive yang muncul.
# Sebaliknya, jika kita menaikkan threshold, maka precision akan meningkat (model lebih yakin saat menyatakan seseorang churn), tetapi recall menurun, karena sebagian pelanggan churn mungkin tidak terdeteksi.
# *   jadi evaluasi ini untuk mengatur treshold di machine learning lanjutan tergantung kebutuhan bisnisnya mau fokus kemana

# %% [markdown]
# | **Skor AUC** | **Kualitas Model**          | **Interpretasi**                          |
# | ------------ | --------------------------- | ----------------------------------------- |
# | 0.5          | **Random Guessing**         | Tidak lebih baik dari tebak-tebakan       |
# | 0.6 – 0.7    | **Poor (Lemah)**            | Model kurang baik dalam klasifikasi       |
# | 0.7 – 0.8    | **Fair (Cukup Baik)**       | Masih bisa diterima, tapi perlu perbaikan |
# | 0.8 – 0.9    | **Good (Bagus)**            | Model cukup akurat dalam membedakan kelas |
# | 0.9 – 1.0    | **Excellent (Sangat Baik)** | Model sangat akurat dan bisa diandalkan   |

# %% [markdown]
# ## Feature importance

# %%
import pandas as pd

feature_names = pipeline.named_steps['preprocessor'].get_feature_names_out()

# Ambil importance dari model
importances = pipeline.named_steps['classifier'].feature_importances_


# Buat DataFrame importance
importance_df = pd.DataFrame({
    'Fitur': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

importance_df['NormalizedImportance'] = importance_df['Importance'] / importance_df['Importance'].sum()
importance_df.drop(columns=['Importance'], inplace=True)

importance_df
# Out:
#                                           Fitur  NormalizedImportance
# 7                   knn_imputer__CashbackAmount              0.179207
# 1                  knn_imputer__WarehouseToHome              0.161149
# 15                   rb_scaling__CashbackAmount              0.135157
# 0                           knn_imputer__Tenure              0.108618
# 6                knn_imputer__DaySinceLastOrder              0.089398
# 4                  knn_imputer__NumberOfAddress              0.080301
# 3                knn_imputer__SatisfactionScore              0.078317
# 2         knn_imputer__NumberOfDeviceRegistered              0.050958
# 5                         knn_imputer__Complain              0.033311
# 14                 onehot__MaritalStatus_Single              0.028523
# 9   onehot__PreferedOrderCat_Laptop & Accessory              0.019562
# 13                onehot__MaritalStatus_Married              0.016142
# 11        onehot__PreferedOrderCat_Mobile Phone              0.010876
# 10              onehot__PreferedOrderCat_Mobile              0.004036
# 12              onehot__PreferedOrderCat_Others              0.002531
# 8              onehot__PreferedOrderCat_Grocery              0.001915

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
ax = sns.barplot(x='NormalizedImportance', y='Fitur', data=importance_df)

for p in ax.patches:
    x = p.get_width()  # Posisi X di akhir bar
    y = p.get_y() + p.get_height() / 2  # Posisi Y di tengah bar
    ax.text(x + 0.0102, y, f'{x:.3f}', va='center', fontsize=10, ha='right')

plt.title('Feature Importance')
plt.show()

# %% [markdown]
# ## Evaluasi

# %% [markdown]
# ### insight

# %% [markdown]
# 1. Handling missing value dengan KNN Imputer karena Lebih Akurat dibanding Imputer Sederhana seperti (mean, median, modus)
#
# 2. Handling data imbalance dengan mencari best sampling imbalance(under sampling : RandomUnderSampler, TomekLinks dan oversampling : SMOTE).
#
# 3. Model dengan feature scalling(Robust scalled karena ada Outlier) pada CashbackAmount yang memiliki scala tinggi memberikan hasil metrik(precision, recall, F1-score) lebih tinggi.
#
# 4. Best Model adalah LightGBM, dengan hasil metrik (precision, recall, F1-score) tinggi.
#
# 5. Penggunaan hyperparameter tuning pada model terbaik (LightGBM) dapat meningkatkan hasil metrik (precision, recall, F1-score)
#
# 6. Penambahan data terbukti meningkatkan performa model
#
# 7. Evaluasi melalui Confusion Matrik menunjukan:
#
#   *   True Positive (TP) = 106 → Model benar memprediksi pelanggan churn
#
#   *   True Negative (TN) = 711 → Model benar memprediksi pelanggan tidak churn
#
#   *   False Positive (FP) = 20 → Model salah prediksi tidak churn → churn
#
#   *   False Negative (FN) = 29 → Model salah prediksi churn → tidak churn
#
#
# 8. Evaluasi ROC Curve dan Thresholding
#
# * AUC = 0.95  Model sangat baik dalam membedakan pelanggan churn dan tidak churn.
#
# * Threshold 0.62 dapat dianggap sebagai titik ambang yang cukup seimbang untuk klasifkasi churn dan not churn dan thershold juga bisa disesuaikan dengan kebutuhan bisnis:
#
#   * Jika ingin meningkatkan recall turunkan threshold dari 0.5 ke 0.4 lebih banyak pelanggan churn terdeteksi, tetapi precision menurun.
#
#   * Jika ingin meningkatkan precision naikkan threshold dari 0.5 ke 0.6 lebih sedikit false positive, tetapi recall menurun.
#
# 9. Berdasarkan analisis feature importance dari model, feature yang paling berpengaruh terhadap model CashbackAmount, WarehouseToHome, CashbackAmount dan Tenure

# %% [markdown]
# ### Rekomendasi

# %% [markdown]
# Fokus Strategi	Rekomendasi
# 1. Akuisisi Data Lebih Banyak melalui Campaign,	Lakukan kampanye pemasaran di berbagai kota besar untuk menjaring lebih banyak pelanggan baru. Semakin banyak pelanggan (baik yang churn maupun tidak), semakin banyak data yang dapat digunakan untuk melatih dan meningkatkan akurasi model.
# 2. Promosi Bertahap Berdasarkan Kematangan Model,	Terapkan strategi promosi dalam tiga tahap, sesuai peningkatan akurasi model:
# - Step 1: Model awal digunakan → promosi tahap awal.
# - Step 2: Model lebih akurat → promosi tahap dua.
# - Step 3: Model sangat akurat → promosi besar-besaran.
# 3. Validasi Target Promosi Berdasarkan Output Model,	Gunakan skor churn dari model untuk menentukan pelanggan target yang paling relevan di setiap tahap promosi, sehingga promosi menjadi lebih tepat sasaran dan efisien.

# %% [markdown]
# manfaat stategi ini :
# - Mengurangi kerugian akibat salah promosi.
#
# - Memastikan promosi tepat sasaran seiring model makin akurat.
#
# - Mendukung proses pengumpulan data berkualitas untuk pengembangan model selanjutnya.

# %% [markdown]
# # SAVE MODEL

# %%
import joblib

# Simpan model
joblib.dump(pipeline, 'best_model_ecomerce_churn.pkl', compress=3) #compress digunakan pada model ukuran besar tapi ini saya pakai hanya opsional agar tahu kegunaannya

# Muat model
model_load = joblib.load('best_model_ecomerce_churn.pkl')

# model siap prediksi
model_load.predict(X)
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %% [markdown]
# # DATA DASHBOARD

# %% [markdown]
# - load data

# %%
import pandas as pd
data_ml = pd.read_csv('data_ml.csv')
data_ml
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0       15.0             29.0                         4  Laptop & Accessory
# 1        7.0             25.0                         4              Mobile
# 2       27.0             13.0                         3  Laptop & Accessory
# 3       20.0             25.0                         4             Fashion
# 4       30.0             15.0                         4              Others
# ...      ...              ...                       ...                 ...
# 3265    25.0             15.0                         5             Fashion
# 3266    26.0              7.0                         4             Grocery
# 3267    28.0              9.0                         5             Fashion
# 3268     8.0              7.0                         2        Mobile Phone
# 3269     2.0              7.0                         3  Laptop & Accessory
#
#       SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                     3        Single                2         0
# 1                     1       Married                2         0
# 2                     1       Married                5         0
# 3                     3      Divorced                7         0
# 4                     4        Single                8         0
# ...                 ...           ...              ...       ...
# 3265                  4       Married                7         0
# 3266                  1       Married                4         0
# 3267                  3       Married                8         0
# 3268                  2        Single                4         0
# 3269                  5       Married                1         0
#
#       DaySinceLastOrder  CashbackAmount  Churn
# 0                   7.0          143.32      0
# 1                   7.0          129.29      0
# 2                   7.0          168.54      0
# 3                   NaN          230.27      0
# 4                   8.0          322.17      0
# ...                 ...             ...    ...
# 3265                8.0          249.90      0
# 3266                9.0          295.99      0
# 3267                1.0          231.86      0
# 3268                4.0          157.80      0
# 3269                2.0          153.73      0
#
# [3270 rows x 11 columns]

# %% [markdown]
# - cek missing value

# %%
data_ml.isna().sum().sort_values(ascending=False)
# Out:
# DaySinceLastOrder           181
# Tenure                      160
# WarehouseToHome             135
# NumberOfDeviceRegistered      0
# PreferedOrderCat              0
# MaritalStatus                 0
# SatisfactionScore             0
# NumberOfAddress               0
# Complain                      0
# CashbackAmount                0
# Churn                         0
# dtype: int64

# %% [markdown]
#  - Imputasi dengan knn imputer

# %%
from sklearn.impute import KNNImputer

data_num = data_ml.select_dtypes(include='number')

# Buat salinan data
data_knn_sub = data_num.copy()

# Inisialisasi dan fit-transform
knn_imputer = KNNImputer(n_neighbors=5)
data_imputed = knn_imputer.fit_transform(data_knn_sub)

# Masukkan kembali hasilnya ke DataFrame
data_knn_imputed = pd.DataFrame(data_imputed, columns=data_num.columns)

data_knn_imputed.isna().sum().sort_values(ascending=False)
# Out:
# Tenure                      0
# WarehouseToHome             0
# NumberOfDeviceRegistered    0
# SatisfactionScore           0
# NumberOfAddress             0
# Complain                    0
# DaySinceLastOrder           0
# CashbackAmount              0
# Churn                       0
# dtype: int64

# %%
data_knn_imputed
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered  SatisfactionScore  \
# 0       15.0             29.0                       4.0                3.0
# 1        7.0             25.0                       4.0                1.0
# 2       27.0             13.0                       3.0                1.0
# 3       20.0             25.0                       4.0                3.0
# 4       30.0             15.0                       4.0                4.0
# ...      ...              ...                       ...                ...
# 3265    25.0             15.0                       5.0                4.0
# 3266    26.0              7.0                       4.0                1.0
# 3267    28.0              9.0                       5.0                3.0
# 3268     8.0              7.0                       2.0                2.0
# 3269     2.0              7.0                       3.0                5.0
#
#       NumberOfAddress  Complain  DaySinceLastOrder  CashbackAmount  Churn
# 0                 2.0       0.0                7.0          143.32    0.0
# 1                 2.0       0.0                7.0          129.29    0.0
# 2                 5.0       0.0                7.0          168.54    0.0
# 3                 7.0       0.0                6.0          230.27    0.0
# 4                 8.0       0.0                8.0          322.17    0.0
# ...               ...       ...                ...             ...    ...
# 3265              7.0       0.0                8.0          249.90    0.0
# 3266              4.0       0.0                9.0          295.99    0.0
# 3267              8.0       0.0                1.0          231.86    0.0
# 3268              4.0       0.0                4.0          157.80    0.0
# 3269              1.0       0.0                2.0          153.73    0.0
#
# [3270 rows x 9 columns]

# %% [markdown]
# - menggabungkan data

# %%
data1 = pd.concat([data_knn_imputed, data_ml[['MaritalStatus','PreferedOrderCat']]], axis=1)
data1
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered  SatisfactionScore  \
# 0       15.0             29.0                       4.0                3.0
# 1        7.0             25.0                       4.0                1.0
# 2       27.0             13.0                       3.0                1.0
# 3       20.0             25.0                       4.0                3.0
# 4       30.0             15.0                       4.0                4.0
# ...      ...              ...                       ...                ...
# 3265    25.0             15.0                       5.0                4.0
# 3266    26.0              7.0                       4.0                1.0
# 3267    28.0              9.0                       5.0                3.0
# 3268     8.0              7.0                       2.0                2.0
# 3269     2.0              7.0                       3.0                5.0
#
#       NumberOfAddress  Complain  DaySinceLastOrder  CashbackAmount  Churn  \
# 0                 2.0       0.0                7.0          143.32    0.0
# 1                 2.0       0.0                7.0          129.29    0.0
# 2                 5.0       0.0                7.0          168.54    0.0
# 3                 7.0       0.0                6.0          230.27    0.0
# 4                 8.0       0.0                8.0          322.17    0.0
# ...               ...       ...                ...             ...    ...
# 3265              7.0       0.0                8.0          249.90    0.0
# 3266              4.0       0.0                9.0          295.99    0.0
# 3267              8.0       0.0                1.0          231.86    0.0
# 3268              4.0       0.0                4.0          157.80    0.0
# 3269              1.0       0.0                2.0          153.73    0.0
#
#      MaritalStatus    PreferedOrderCat
# 0           Single  Laptop & Accessory
# 1          Married              Mobile
# 2          Married  Laptop & Accessory
# 3         Divorced             Fashion
# 4           Single              Others
# ...            ...                 ...
# 3265       Married             Fashion
# 3266       Married             Grocery
# 3267       Married             Fashion
# 3268        Single        Mobile Phone
# 3269       Married  Laptop & Accessory
#
# [3270 rows x 11 columns]

# %% [markdown]
# - cel missing value lagi

# %%
data1.isna().sum()
# Out:
# Tenure                      0
# WarehouseToHome             0
# NumberOfDeviceRegistered    0
# SatisfactionScore           0
# NumberOfAddress             0
# Complain                    0
# DaySinceLastOrder           0
# CashbackAmount              0
# Churn                       0
# MaritalStatus               0
# PreferedOrderCat            0
# dtype: int64

# %% [markdown]
# - Ubah value di data churn dan complain 0:tidak 1:iya

# %%
data1[['Churn','Complain']] = data1[['Churn','Complain']].replace({0: 'tidak', 1: 'iya'})
data1
# Out:
#       Tenure  WarehouseToHome  NumberOfDeviceRegistered  SatisfactionScore  \
# 0       15.0             29.0                       4.0                3.0
# 1        7.0             25.0                       4.0                1.0
# 2       27.0             13.0                       3.0                1.0
# 3       20.0             25.0                       4.0                3.0
# 4       30.0             15.0                       4.0                4.0
# ...      ...              ...                       ...                ...
# 3265    25.0             15.0                       5.0                4.0
# 3266    26.0              7.0                       4.0                1.0
# 3267    28.0              9.0                       5.0                3.0
# 3268     8.0              7.0                       2.0                2.0
# 3269     2.0              7.0                       3.0                5.0
#
#       NumberOfAddress Complain  DaySinceLastOrder  CashbackAmount  Churn  \
# 0                 2.0    tidak                7.0          143.32  tidak
# 1                 2.0    tidak                7.0          129.29  tidak
# 2                 5.0    tidak                7.0          168.54  tidak
# 3                 7.0    tidak                6.0          230.27  tidak
# 4                 8.0    tidak                8.0          322.17  tidak
# ...               ...      ...                ...             ...    ...
# 3265              7.0    tidak                8.0          249.90  tidak
# 3266              4.0    tidak                9.0          295.99  tidak
# 3267              8.0    tidak                1.0          231.86  tidak
# 3268              4.0    tidak                4.0          157.80  tidak
# 3269              1.0    tidak                2.0          153.73  tidak
#
#      MaritalStatus    PreferedOrderCat
# 0           Single  Laptop & Accessory
# 1          Married              Mobile
# 2          Married  Laptop & Accessory
# 3         Divorced             Fashion
# 4           Single              Others
# ...            ...                 ...
# 3265       Married             Fashion
# 3266       Married             Grocery
# 3267       Married             Fashion
# 3268        Single        Mobile Phone
# 3269       Married  Laptop & Accessory
#
# [3270 rows x 11 columns]

# %%
data1.to_csv('data_ecomerce_churn.csv', index=False)
